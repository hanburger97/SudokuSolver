# %%
from __future__ import division, print_function, absolute_import

import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

# Training Parameters
learning_rate = 0.001
num_steps = 500
batch_size = 128
display_step = 10

# Network Parameters
num_input = 784 # MNIST data input (img shape: 28*28)
num_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
X = tf.placeholder(tf.float32, [None, num_input])
Y = tf.placeholder(tf.float32, [None, num_classes])
keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
class Brain:
    
    def __init__():
        
        pass
    
    def conv2d(self, x, W, b, strides=1):
        # Conv2D wrapper, with bias and relu activation
        x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
        x = tf.nn.bias_add(x, b)
        return tf.nn.relu(x)


    def maxpool2d(self, x, k=2):
        # MaxPool2D wrapper
        return tf.nn.max_pool( x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


    # Create model
    def conv_net(self, x, weights, biases, dropout):
        # MNIST data input is a 1-D vector of 784 features (28*28 pixels)
        # Reshape to match picture format [Height x Width x Channel]
        # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
        x = tf.reshape(x, shape=[-1, 28, 28, 1])

        # Convolution Layer
        conv1 = self.conv2d(x, weights['wc1'], biases['bc1'])
        # Max Pooling (down-sampling)
        conv1 = maxpool2d(conv1, k=2)

        # Convolution Layer
        conv2 = self.conv2d(conv1, weights['wc2'], biases['bc2'])
        # Max Pooling (down-sampling)
        conv2 = self.maxpool2d(conv2, k=2)

        # Fully connected layer
        # Reshape conv2 output to fit fully connected layer input
        fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
        fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
        fc1 = tf.nn.relu(fc1)
        # Apply Dropout
        fc1 = tf.nn.dropout(fc1, dropout)

        # Output, class prediction
        out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
        return out

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # MNIST data input is a 1-D vector of 784 features (28*28 pixels)
    # Reshape to match picture format [Height x Width x Channel]
    # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, num_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# Construct model
logits = conv_net(X, weights, biases, keep_prob)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)


# Evaluate model
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()

# %%
# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    for step in range(1, num_steps+1):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, keep_prob: 0.8})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y,
                                                                 keep_prob: 1.0})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    print("Optimization Finished!")

    # Calculate accuracy for 256 MNIST test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: mnist.test.images[:256],
                                      Y: mnist.test.labels[:256],
                                      keep_prob: 1.0}))
    savePath = saver.save(sess, './')
# Out:
# Step 1, Minibatch Loss= 49370.9219, Training Accuracy= 0.125
# Step 10, Minibatch Loss= 22499.0664, Training Accuracy= 0.320
# Step 20, Minibatch Loss= 8905.9395, Training Accuracy= 0.562
# Step 30, Minibatch Loss= 6571.8101, Training Accuracy= 0.633
# Step 40, Minibatch Loss= 4972.9624, Training Accuracy= 0.758
# Step 50, Minibatch Loss= 4033.1748, Training Accuracy= 0.797
# Step 60, Minibatch Loss= 3451.4492, Training Accuracy= 0.773
# Step 70, Minibatch Loss= 2543.8093, Training Accuracy= 0.836
# Step 80, Minibatch Loss= 2119.7710, Training Accuracy= 0.867
# Step 90, Minibatch Loss= 1753.4708, Training Accuracy= 0.891
# Step 100, Minibatch Loss= 2223.1719, Training Accuracy= 0.852
# Step 110, Minibatch Loss= 1478.0292, Training Accuracy= 0.922
# Step 120, Minibatch Loss= 2480.9175, Training Accuracy= 0.875
# Step 130, Minibatch Loss= 2474.0112, Training Accuracy= 0.859
# Step 140, Minibatch Loss= 2006.6003, Training Accuracy= 0.875
# Step 150, Minibatch Loss= 831.4312, Training Accuracy= 0.938
# Step 160, Minibatch Loss= 1242.4788, Training Accuracy= 0.930
# Step 170, Minibatch Loss= 1728.8254, Training Accuracy= 0.883
# Step 180, Minibatch Loss= 1223.6752, Training Accuracy= 0.914
# Step 190, Minibatch Loss= 622.2521, Training Accuracy= 0.938
# Step 200, Minibatch Loss= 1468.1155, Training Accuracy= 0.922
# Step 210, Minibatch Loss= 1198.8387, Training Accuracy= 0.891
# Step 220, Minibatch Loss= 1719.3794, Training Accuracy= 0.898
# Step 230, Minibatch Loss= 782.3592, Training Accuracy= 0.930
# Step 240, Minibatch Loss= 452.8902, Training Accuracy= 0.953
# Step 250, Minibatch Loss= 363.7947, Training Accuracy= 0.953
# Step 260, Minibatch Loss= 832.3814, Training Accuracy= 0.930
# Step 270, Minibatch Loss= 619.8566, Training Accuracy= 0.953
# Step 280, Minibatch Loss= 1083.3398, Training Accuracy= 0.922
# Step 290, Minibatch Loss= 391.7394, Training Accuracy= 0.945
# Step 300, Minibatch Loss= 836.0231, Training Accuracy= 0.961
# Step 310, Minibatch Loss= 1272.0264, Training Accuracy= 0.938
# Step 320, Minibatch Loss= 422.3533, Training Accuracy= 0.953
# Step 330, Minibatch Loss= 1265.5352, Training Accuracy= 0.945
# Step 340, Minibatch Loss= 471.2351, Training Accuracy= 0.938
# Step 350, Minibatch Loss= 722.7446, Training Accuracy= 0.938
# Step 360, Minibatch Loss= 1144.4589, Training Accuracy= 0.922
# Step 370, Minibatch Loss= 655.5903, Training Accuracy= 0.914
# Step 380, Minibatch Loss= 438.9310, Training Accuracy= 0.961
# Step 390, Minibatch Loss= 567.4170, Training Accuracy= 0.938
# Step 400, Minibatch Loss= 939.1768, Training Accuracy= 0.922
# Step 410, Minibatch Loss= 131.4188, Training Accuracy= 0.977
# Step 420, Minibatch Loss= 735.8481, Training Accuracy= 0.961
# Step 430, Minibatch Loss= 359.1736, Training Accuracy= 0.961
# Step 440, Minibatch Loss= 170.2012, Training Accuracy= 0.977
# Step 450, Minibatch Loss= 448.9258, Training Accuracy= 0.953
# Step 460, Minibatch Loss= 1216.8400, Training Accuracy= 0.898
# Step 470, Minibatch Loss= 477.4468, Training Accuracy= 0.969
# Step 480, Minibatch Loss= 528.6797, Training Accuracy= 0.961
# Step 490, Minibatch Loss= 826.6053, Training Accuracy= 0.953
# Step 500, Minibatch Loss= 785.3226, Training Accuracy= 0.969
# Optimization Finished!
# Testing Accuracy: 0.972656
